# %%
import pandas as pd
import bokeh as bk
import seaborn as sbn

from matplotlib.pyplot import *
# %matplotlib inline

# %%
df = pd.read_excel("DATASET_DESEMPENHO_RENDIMENTO_UFF_FORMADOS_2013-2017.xlsx")

# %%
df.head(27)
# Out:
#          IDALUNO   CR  PERIODO    CURSO NOMEDIPLOMA LOCALIDADE
# 0   100000125581  9.8    20131  DIREITO     DIREITO    NITERÓI
# 1   100000125581  9.4    20132  DIREITO     DIREITO    NITERÓI
# 2   100000125581  9.2    20141  DIREITO     DIREITO    NITERÓI
# 3   100000125581  9.4    20142  DIREITO     DIREITO    NITERÓI
# 4   100000125581  9.4    20151  DIREITO     DIREITO    NITERÓI
# 5   100000125581  9.5    20152  DIREITO     DIREITO    NITERÓI
# 6   100000125581  9.2    20161  DIREITO     DIREITO    NITERÓI
# 7   100000125581  9.0    20162  DIREITO     DIREITO    NITERÓI
# 8   100000125581  9.8    20171  DIREITO     DIREITO    NITERÓI
# 9   100000125582  8.9    20131  DIREITO     DIREITO    NITERÓI
# 10  100000125582  8.4    20132  DIREITO     DIREITO    NITERÓI
# 11  100000125582  7.3    20141  DIREITO     DIREITO    NITERÓI
# 12  100000125582  8.7    20142  DIREITO     DIREITO    NITERÓI
# 13  100000125582  9.5    20151  DIREITO     DIREITO    NITERÓI
# 14  100000125582  8.4    20152  DIREITO     DIREITO    NITERÓI
# 15  100000125582  9.2    20161  DIREITO     DIREITO    NITERÓI
# 16  100000125582  9.3    20162  DIREITO     DIREITO    NITERÓI
# 17  100000125582  9.1    20171  DIREITO     DIREITO    NITERÓI
# 18  100000125583  8.2    20131  DIREITO     DIREITO    NITERÓI
# 19  100000125583  7.8    20132  DIREITO     DIREITO    NITERÓI
# 20  100000125583  8.8    20141  DIREITO     DIREITO    NITERÓI
# 21  100000125583  8.6    20142  DIREITO     DIREITO    NITERÓI
# 22  100000125583  8.9    20151  DIREITO     DIREITO    NITERÓI
# 23  100000125583  8.7    20152  DIREITO     DIREITO    NITERÓI
# 24  100000125583  8.9    20161  DIREITO     DIREITO    NITERÓI
# 25  100000125583  9.5    20162  DIREITO     DIREITO    NITERÓI
# 26  100000125583  8.8    20171  DIREITO     DIREITO    NITERÓI

# %%
print(df.CR.describe())
# Out:
# count    3291.000000
# mean        6.089341
# std         3.404948
# min         0.000000
# 25%         1.000000
# 50%         7.700000
# 75%         8.700000
# max        10.000000
# Name: CR, dtype: float64

# %%
print(df.PERIODO.describe())
# Out:
# count     3291.000000
# mean     20148.580978
# std         12.228712
# min      20131.000000
# 25%      20141.000000
# 50%      20151.000000
# 75%      20161.000000
# max      20171.000000
# Name: PERIODO, dtype: float64

# %%
df.CR.hist();

# %%
scatter(df.PERIODO, df.CR, s=10, c='gray', marker='x', data=df);

# %%
sbn.distplot(df.CR, hist=True,bins=10);

# %%
sbn.distplot(df.PERIODO, hist=True,bins=10);

# %%
sbn.pairplot(df)

# %%
sbn.boxplot(df.PERIODO, df.CR)

# %%
sbn.barplot(x='PERIODO', y='CR', data= df)

# %%
sbn.jointplot(x='PERIODO', y='CR', data= df) #kind='kde'

# %%
sbn.jointplot(x='PERIODO', y='CR', data= df, kind='kde')

# %%
sbn.pairplot(df, palette='viridis')

# %%
sbn.countplot(y='PERIODO', data=df)

# %%
sbn.stripplot(x='PERIODO', y='CR', data= df)
